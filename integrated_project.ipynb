# %% [markdown]
# # objetivo del proyecto
# Identificar patrones que determinen si un juego tiene éxito o no. detectar proyectos prometedores y planificar campañas publicitarias.

# %%
# se importan las principales librerias a usar,     que se iran actualizando mediante el desarrollo del proyecto
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('games.csv')
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# se reemplaza el nombre de las columnas a minusculas.
df.columns = df.columns.str.lower()

# %%
# se verifica nuevamente el DataFrame
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
# se organiza el dataframe por ano de lanzamiento para mayor comprension y analisis
df.sort_values(by=['year_of_release'], ascending=False, inplace=True)

# %%
df.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16714      Winning Post 8 2016      PSV           2016.0    Simulation
# 14400               DiRT Rally       PC           2016.0        Racing
# 2024                  NBA 2K17     XOne           2016.0        Sports
# 15456  Carmageddon: Max Damage     XOne           2016.0        Action
# 14385         Tokyo Xanadu eX+      PS4           2016.0  Role-Playing
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 16714      0.00      0.00      0.01         0.00           NaN        NaN
# 14400      0.00      0.03      0.00         0.00          86.0        8.7
# 2024       0.86      0.06      0.00         0.11          90.0        6.2
# 15456      0.01      0.01      0.00         0.00          52.0        7.1
# 14385      0.00      0.00      0.03         0.00           NaN        NaN
#
#       rating
# 16714    NaN
# 14400      E
# 2024       E
# 15456      M
# 14385    NaN

# %%
# se verifica la cantidad de valores ausentes en el DataFrame
df.isnull().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
# se reemplaza todos los valores nulo por 0.
df[['year_of_release','critic_score','user_score','rating']] = df[['year_of_release','critic_score','user_score','rating']].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16715 entries, 16714 to 16522
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  float64
#  9   user_score       16715 non-null  object
#  10  rating           16715 non-null  object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ## valores ausentes
#
# se reemplazan los valores ausentes por 0, ya que al realizar el analisis del dataframe el valor 0 corresponde al ano de lanzamiento del juego, se decide rellenar con 0 para no perder informacion relevante tal como el rating de los juegos, y el valor de la critica.

# %%
# se cambian el tipo de datos de algunas columnas del dataframe
df[['year_of_release','critic_score']] = df[['year_of_release','critic_score']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16715 entries, 16714 to 16522
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     16715 non-null  int64
#  9   user_score       16715 non-null  object
#  10  rating           16715 non-null  object
# dtypes: float64(4), int64(2), object(5)
# memory usage: 1.5+ MB

# %%
df.query('(na_sales > 1) and (jp_sales < 1) and (eu_sales < 1) and (other_sales < 1) and user_score == "tbd"').head()
# Out:
#                            name platform  year_of_release       genre  \
# 718             Just Dance Kids      Wii             2010        Misc
# 645                uDraw Studio      Wii             2010        Misc
# 1284   Disney Sing It: Pop Hits      Wii             2009        Misc
# 1070               Game Party 3      Wii             2009      Puzzle
# 726   Dance Dance Revolution X2      PS2             2009  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 718       1.52      0.54       0.0         0.18             0        tbd
# 645       1.65      0.57       0.0         0.20            71        tbd
# 1284      1.07      0.28       0.0         0.13             0        tbd
# 1070      1.40      0.16       0.0         0.12            37        tbd
# 726       1.09      0.85       0.0         0.28             0        tbd
#
#      rating
# 718       E
# 645       E
# 1284      E
# 1070      E
# 726    E10+

# %% [markdown]
# se puede inferir que la abreviatura "tbd" corresponde cuando existen ventas menores a 1 millon de dolares en alguno de los 4 mercados analizados
